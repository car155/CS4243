# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Car

# %%
car = cv2.imread("images/carpixel-1976-ferrari-512-bb-.jpg")
car_gray = cv2.cvtColor(car, cv2.COLOR_BGR2GRAY)

# %%
hist,bins = np.histogram(car_gray.flatten(), 256, [0,256])
 
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()

plt.plot(cdf_normalized, color='b')
plt.hist(car_gray.flatten(), 256, [0,256], color='r')
plt.xlim([0,256])
plt.legend(('cdf', 'histogram'), loc='upper left')
plt.show()

# %%
print("Dynamic Range: ({}, {})".format(np.amin(car_gray), np.amax(car_gray)))
# Out:
# Dynamic Range: (0, 255)

# %% [markdown]
# ### Cat

# %%
cat = cv2.imread("images/cat.bmp")
cat_gray = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)

# %%
hist,bins = np.histogram(cat_gray.flatten(), 256, [0,256])
 
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()

plt.plot(cdf_normalized, color='b')
plt.hist(cat_gray.flatten(), 256, [0,256], color='b', alpha=0.3)
plt.xlim([0,256])
plt.legend(('cdf', 'histogram'), loc='upper left')
plt.show()

# %%
print("Dynamic Range: ({}, {})".format(np.amin(cat_gray), np.amax(cat_gray)))
# Out:
# Dynamic Range: (5, 253)
